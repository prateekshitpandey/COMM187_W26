# %% [markdown]
# # COMM 187: Data Science in Communication Research, Winter 2026
# ## Hackathon #1
#
# **Date:** Tue, Feb 3, 2026 \
# **Time:** 5 PM - 7:20 PM\
# **Maximum points:** 10
#
# <span style="color:red">Follow the instruction sheet provided to you by the instructors.</span>

# %% [markdown]
# ### GROUP [number]: [Name of group]
#
# **Members**:
#  - Full name 1
#  - Full name 2
#  - Full name 3
#
# **Question Set:** A, B, or C?

# %% [markdown]
# ### Loading data (1 point)

# %%
## Write your code below this line

# %% [markdown]
# ### Descriptive Statistics (2 points)

# %%
## Write your code below this line

# %% [markdown]
# ### Q1. (2 points)

# %%
## Write your code below this line

# %% [markdown]
# ### Q2. (2 points)

# %%
## Write your code below this line

# %% [markdown]
# ### Q3. (2 points)

# %%
## Write your code below this line

# %% [markdown]
# ### Summary (1 point)

# %% [markdown]
# Replace this text with your summary of conclusions.
