# %% [markdown]
# # COMM 187: Data Science in Communication Research, Winter 2026
#
# ## Week #9: Advanced Data Visualizations

# %% [markdown]
# Welcome to the Week #9 Coding Lab for COMM 187: Data Science in Communication Research!
#
# Today's lesson plan:
#  - Loading datasets for final project

# %% [markdown]
# In the past three weeks, we have learned the following types of plots:
#
#  - **Histograms** -- for visualizing data distribution and description
#  - **Scatterplots** -- for visualizing relationships between two variables
#  - **Box plots** -- for visualizing difference in means between groups; ideal for visualizing t-tests and ANOVA
#  - **Joint plots** -- for visualizing scatterplots with more information
#  - **Violin plots** -- for visualizing difference in means between groups but with more info about distributions than box plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Global Preferences Survey

# %% [markdown]
# ### Meta Social Capital Atlas - US High Schools

# %% [markdown]
# ### Meta Social Capital Atlas - US Zip Codes

# %% [markdown]
# ### Pew Local News Survey

# %% [markdown]
# ### Pew Research Center International Science Survey

# %% [markdown]
# ### Wellcome Global Monitor 2020 Covid-19
